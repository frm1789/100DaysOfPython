# %% [markdown]
# <a href="https://colab.research.google.com/github/frm1789/100DaysOfPython/blob/main/Plotting_with_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## The simplest example in Python

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3]
y = [3, 5, 4]

plt.plot(x, y)
plt.show()
